# %%
from google.colab import drive
drive.mount("/content/drive")

import os
DRIVE_ROOT = "/content/drive/MyDrive/ghostshot"
os.makedirs(DRIVE_ROOT, exist_ok=True)
print(f"Drive mounted. Project root: {DRIVE_ROOT}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted. Project root: /content/drive/MyDrive/ghostshot

# %%
REPO_URL = "https://github.com/mohamedaazouni10-code/ghostshot.git"
REPO_DIR = "/content/ghostshot"

import os
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
    print("Repo cloned.")
else:
    # %cd {REPO_DIR}
    # !git pull
    print("Repo updated.")

# %cd {REPO_DIR}
# !ls
# Out:
# /content/ghostshot
# Already up to date.
# Repo updated.
# /content/ghostshot
# configs  README.md  requirements.txt  src

# %%
# !git pull
# !pip install -q -r requirements.txt

import torch
print(f"PyTorch: {torch.__version__} | CUDA: {torch.cuda.is_available()}")
# Out:
# Already up to date.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.3 which is incompatible.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# tobler 0.14.0 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# tobler 0.14.0 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# tobler 0.14.0 requires tqdm>=4.67, but you have tqdm 4.66.1 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.11.4 which is incompatible.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.0 which is incompatible.
# pointpats 2.5.5 requires matplotlib>=3.9, but you have matplotlib 3.8.2 which is incompatible.
# pointpats 2.5.5 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# pointpats 2.5.5 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# spopt 0.7.0 requires scikit-learn>=1.4.0, but you have scikit-learn 1.3.2 which is incompatible.
# spopt 0.7.0 requires scipy>=1.12.0, but you have scipy 1.11.4 which is incompatible.
# dataproc-spark-connect 1.1.0 requires tqdm>=4.67, but you have tqdm 4.66.1 which is incompatible.
# albucore 0.0.24 requires opencv-python-headless>=4.9.0.80, but you have opencv-python-headless 4.8.1.78 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# imbalanced-learn 0.14.1 requires scikit-learn<2,>=1.4.2, but you have scikit-learn 1.3.2 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.0 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# xarray-einstats 0.10.0 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# xarray 2025.12.0 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# jaxlib 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# google-adk 1.29.0 requires PyYAML<7.0.0,>=6.0.2, but you have pyyaml 6.0.1 which is incompatible.
# inequality 1.1.2 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# cuml-cu12 26.2.0 requires scikit-learn>=1.5, but you have scikit-learn 1.3.2 which is incompatible.
# cuml-cu12 26.2.0 requires scipy>=1.13.0, but you have scipy 1.11.4 which is incompatible.
# mapclassify 2.10.0 requires scikit-learn>=1.4, but you have scikit-learn 1.3.2 which is incompatible.
# mapclassify 2.10.0 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.11.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# esda 2.9.0 requires scikit-learn>=1.4, but you have scikit-learn 1.3.2 which is incompatible.
# esda 2.9.0 requires scipy>=1.12, but you have scipy 1.11.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# jax 0.7.2 requires scipy>=1.13, but you have scipy 1.11.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.0 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# libpysal 4.14.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.3.2 which is incompatible.
# libpysal 4.14.1 requires scipy>=1.12.0, but you have scipy 1.11.4 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.
# PyTorch: 2.10.0+cu128 | CUDA: True

# %%
# !pip install -q timm torchvision

# %%
import sys
sys.path.insert(0, "/content/ghostshot")

# %%
# !pip install -q "albumentations>=1.4.0" "numpy>=2.0"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.4/369.4 kB 16.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas 2.1.3 requires numpy<2,>=1.26.0; python_version >= "3.12", but you have numpy 2.4.4 which is incompatible.
# scikit-learn 1.3.2 requires numpy<2.0,>=1.17.3, but you have numpy 2.4.4 which is incompatible.
# matplotlib 3.8.2 requires numpy<2,>=1.21, but you have numpy 2.4.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.3 which is incompatible.
# umap-learn 0.5.12 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# tobler 0.14.0 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# tobler 0.14.0 requires tqdm>=4.67, but you have tqdm 4.66.1 which is incompatible.
# hdbscan 0.8.42 requires scikit-learn>=1.6, but you have scikit-learn 1.3.2 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.4 which is incompatible.
# pointpats 2.5.5 requires matplotlib>=3.9, but you have matplotlib 3.8.2 which is incompatible.
# pointpats 2.5.5 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.4 which is incompatible.
# spopt 0.7.0 requires scikit-learn>=1.4.0, but you have scikit-learn 1.3.2 which is incompatible.
# datasets 4.0.0 requires tqdm>=4.66.3, but you have tqdm 4.66.1 which is incompatible.
# imbalanced-learn 0.14.1 requires scikit-learn<2,>=1.4.2, but you have scikit-learn 1.3.2 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# xarray 2025.12.0 requires pandas>=2.2, but you have pandas 2.1.3 which is incompatible.
# cuml-cu12 26.2.0 requires scikit-learn>=1.5, but you have scikit-learn 1.3.2 which is incompatible.
# mapclassify 2.10.0 requires scikit-learn>=1.4, but you have scikit-learn 1.3.2 which is incompatible.
# esda 2.9.0 requires scikit-learn>=1.4, but you have scikit-learn 1.3.2 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.
# libpysal 4.14.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.3.2 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 2.1.3 which is incompatible.

# %%
# !pip install -q timm torchvision "albumentations>=1.4.0" "scikit-learn>=1.4" "pandas>=2.2" "matplotlib>=3.9" "tqdm>=4.67" "scipy>=1.13" wandb deepface facenet-pytorch
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 98.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 95.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.2 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.3 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.2 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.2 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.2 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.

# %%
import sys
sys.path.insert(0, "/content/ghostshot")

# %%
from src.utils import run_all_checks
run_all_checks()
# Out:
# ========================================================
#   GhostShot — Environment Check
#   Python 3.12.13
#   PyTorch 2.10.0+cu128
# ========================================================
#
# ── Packages ─────────────────────────────────────────────
#   ✓  torch                  2.10.0+cu128
#   ✓  torchvision            0.25.0+cu128
#   ✓  cv2                    4.13.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8727/2045296716.py in <cell line: 0>()
#       1 from src.utils import run_all_checks
# ----> 2 run_all_checks()
#
# /content/ghostshot/src/utils/env_check.py in run_all_checks()
#      92
#      93     print("\n── Packages ─────────────────────────────────────────────")
# ---> 94     pkg_ok  = check_packages()
#      95     gpu_ok  = check_gpu()
#      96     bb_ok   = check_backbone()
#
# /content/ghostshot/src/utils/env_check.py in check_packages()
#      18     for pkg in REQUIRED:
#      19         try:
# ---> 20             mod = importlib.import_module(pkg)
#      21             version = getattr(mod, "__version__", "n/a")
#      22             print(f"  ✓  {pkg:<22} {version}")
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.12/dist-packages/timm/__init__.py in <module>
#       1 from .version import __version__
#       2 from .layers import is_scriptable, is_exportable, set_scriptable, set_exportable
# ----> 3 from .models import create_model, list_models, list_pretrained, is_model, list_modules, model_entrypoint, \
#       4     is_model_pretrained, get_pretrained_cfg, get_pretrained_cfg_value
#
# /usr/local/lib/python3.12/dist-packages/timm/models/__init__.py in <module>
# ----> 1 from .beit import *
#       2 from .byoanet import *
#       3 from .byobnet import *
#       4 from .cait import *
#       5 from .coat import *
#
# /usr/local/lib/python3.12/dist-packages/timm/models/beit.py in <module>
#      47 from torch.utils.checkpoint import checkpoint
#      48
# ---> 49 from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
#      50 from timm.layers import PatchEmbed, Mlp, SwiGLU, LayerNorm, DropPath, trunc_normal_, use_fused_attn
#      51 from timm.layers import resample_patch_embed, resample_abs_pos_embed, resize_rel_pos_bias_table
#
# /usr/local/lib/python3.12/dist-packages/timm/data/__init__.py in <module>
#       3 from .config import resolve_data_config, resolve_model_data_config
#       4 from .constants import *
# ----> 5 from .dataset import ImageDataset, IterableImageDataset, AugMixDataset
#       6 from .dataset_factory import create_dataset
#       7 from .dataset_info import DatasetInfo, CustomDatasetInfo
#
# /usr/local/lib/python3.12/dist-packages/timm/data/dataset.py in <module>
#      11 from PIL import Image
#      12
# ---> 13 from .readers import create_reader
#      14
#      15 _logger = logging.getLogger(__name__)
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/__init__.py in <module>
# ----> 1 from .reader_factory import create_reader
#       2 from .img_extensions import *
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/reader_factory.py in <module>
#       1 import os
#       2
# ----> 3 from .reader_image_folder import ReaderImageFolder
#       4 from .reader_image_in_tar import ReaderImageInTar
#       5
#
# /usr/local/lib/python3.12/dist-packages/timm/data/readers/reader_image_folder.py in <module>
#       9 from typing import Dict, List, Optional, Set, Tuple, Union
#      10
# ---> 11 from timm.utils.misc import natural_key
#      12
#      13 from .class_map import load_class_map
#
# /usr/local/lib/python3.12/dist-packages/timm/utils/__init__.py in <module>
#      13 from .model_ema import ModelEma, ModelEmaV2
#      14 from .random import random_seed
# ---> 15 from .summary import update_summary, get_outdir
#
# /usr/local/lib/python3.12/dist-packages/timm/utils/summary.py in <module>
#       7 from collections import OrderedDict
#       8 try:
# ----> 9     import wandb
#      10 except ImportError:
#      11     pass
#
# /usr/local/lib/python3.12/dist-packages/wandb/__init__.py in <module>
#      25 from wandb.errors.term import termsetup, termlog, termerror, termwarn
#      26
# ---> 27 from wandb import sdk as wandb_sdk
#      28
#      29 import wandb
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/__init__.py in <module>
#      23
#      24 from . import wandb_helper as helper
# ---> 25 from .artifacts.artifact import Artifact
#      26 from .wandb_alerts import AlertLevel
#      27 from .wandb_config import Config
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/artifacts/artifact.py in <module>
#      34
#      35 import wandb
# ---> 36 from wandb import data_types, env, util
#      37 from wandb.apis.normalize import normalize_exceptions
#      38 from wandb.apis.public import ArtifactCollection, ArtifactFiles, RetryingClient, Run
#
# /usr/local/lib/python3.12/dist-packages/wandb/data_types.py in <module>
#      30 from wandb.sdk.lib import filesystem
#      31
# ---> 32 from .sdk.data_types import _dtypes
#      33 from .sdk.data_types._private import MEDIA_TMP
#      34 from .sdk.data_types.base_types.media import (
#
# /usr/local/lib/python3.12/dist-packages/wandb/sdk/data_types/_dtypes.py in <module>
#     391     NumberType.types.append(np.float32)
#     392     NumberType.types.append(np.float64)
# --> 393     NumberType.types.append(np.float_)
#     394     NumberType.types.append(np.complex64)
#     395     NumberType.types.append(np.complex128)
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#
# AttributeError: `np.float_` was removed in the NumPy 2.0 release. Use `np.float64` instead.

# %% [markdown]
# ************************************

# %%
# !pip install -q timm torchvision \
  "albumentations>=1.4.15" \
  "scikit-learn>=1.5" \
  "wandb>=0.17" \
  "pandas>=2.2" \
  "matplotlib>=3.9" \
  "tqdm>=4.67" \
  "scipy>=1.13" \
  deepface facenet-pytorch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.2/27.2 MB 81.0 MB/s eta 0:00:00

# %%
import sys
sys.path.insert(0, "/content/ghostshot")

# %%
from src.utils import run_all_checks
run_all_checks()
# Out:
# ========================================================
#   GhostShot — Environment Check
#   Python 3.12.13
#   PyTorch 2.10.0+cu128
# ========================================================
#
# ── Packages ─────────────────────────────────────────────
#   ✓  torch                  2.10.0+cu128
#   ✓  torchvision            0.25.0+cu128
#   ✓  cv2                    4.13.0
#   ✓  timm                   0.9.12
#   ✓  albumentations         2.0.8
#   ✓  wandb                  0.26.0
#   ✓  sklearn                1.8.0
#   ✓  deepface               0.0.93
#   ✓  facenet_pytorch        n/a
#   ✓  tqdm                   4.67.3
#
# ── GPU ──────────────────────────────────────────────────
#   ✓  GPU 0: Tesla T4 | 14.6 GB VRAM
#   ✓  CUDA version : 12.8
#   ✓  cuDNN version: 91002
#
# ── Model backbone ───────────────────────────────────────
#   ✓  EfficientNet-B4 loaded (19.3M parameters)
#
# ── Face stack ───────────────────────────────────────────
#   ✓  MTCNN (facenet-pytorch)
# 26-04-22 12:31:00 - Directory /root/.deepface has been created
# 26-04-22 12:31:00 - Directory /root/.deepface/weights has been created
#   ✓  DeepFace
#
# ── Summary ──────────────────────────────────────────────
#   ✓  Packages
#   ✓  GPU
#   ✓  Backbone
#   ✓  Face stack
# ========================================================
#   All checks passed — ready to build GhostShot!
# ========================================================

# %%
DRIVE_ROOT = "/content/drive/MyDrive/ghostshot"

# %%
import os
os.chdir("/content/ghostshot")
print(os.getcwd())
# Out:
# /content/ghostshot

# %%
import os

os.chdir("/content/ghostshot")

# Create local folders first
local_folders = [
    "data/raw", "data/processed", "data/attack_samples",
    "models/checkpoints", "results"
]
for f in local_folders:
    os.makedirs(f, exist_ok=True)
    print(f"Created local: {f}")
# Out:
# Created local: data/raw
# Created local: data/processed
# Created local: data/attack_samples
# Created local: models/checkpoints
# Created local: results

# %%
DRIVE_ROOT = "/content/drive/MyDrive/ghostshot"

links = {
    f"{DRIVE_ROOT}/data/raw":            "data/raw",
    f"{DRIVE_ROOT}/data/processed":      "data/processed",
    f"{DRIVE_ROOT}/data/attack_samples": "data/attack_samples",
    f"{DRIVE_ROOT}/models/checkpoints":  "models/checkpoints",
    f"{DRIVE_ROOT}/results":             "results",
}

for drive_path, local_link in links.items():
    if os.path.islink(local_link):
        print(f"Already linked: {local_link}")
    elif os.path.isdir(local_link):
        os.rmdir(local_link)
        os.symlink(drive_path, local_link)
        print(f"Linked: {local_link} → {drive_path}")
    else:
        os.symlink(drive_path, local_link)
        print(f"Linked: {local_link} → {drive_path}")
# Out:
# Linked: data/raw → /content/drive/MyDrive/ghostshot/data/raw
# Linked: data/processed → /content/drive/MyDrive/ghostshot/data/processed
# Linked: data/attack_samples → /content/drive/MyDrive/ghostshot/data/attack_samples
# Linked: models/checkpoints → /content/drive/MyDrive/ghostshot/models/checkpoints
# Linked: results → /content/drive/MyDrive/ghostshot/results

# %% [markdown]
# Cell 6 — Load Config

# %%
import yaml

with open("configs/base.yaml") as f:
    cfg = yaml.safe_load(f)

print(f"Project : {cfg['project']['name']} v{cfg['project']['version']}")
print(f"Backbone: {cfg['model']['backbone']}")
print(f"Epochs  : {cfg['training']['epochs']}")
print(f"Batch   : {cfg['training']['batch_size']}")
# Out:
# Project : ghostshot v1.0
# Backbone: efficientnet_b4
# Epochs  : 30
# Batch   : 32

# %% [markdown]
# Cell 7 — Set Seed and Device

# %%
from src.utils import set_seed, get_device

set_seed(cfg["project"]["seed"])
device = get_device(cfg)
print(f"Ready. Device = {device}")
# Out:
# [seed] All random seeds set to 42
# [device] Using configured device: cuda
# Ready. Device = cuda
